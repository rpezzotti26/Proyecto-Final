# %% [markdown]
# ### Tabla resumen de resultados por arquitectura
# | Arquitectura | Accuracy| Precision | Recall | F1-score | Tiempo (s) |
# |------------- |---------|-----------|--------|----------|------------|
# | Arquitectura 1 | 0.880 |    0.880  | 0.870  |   0.874  |     7.6    |
# | Arquitectura 2 | 0.876 |    0.882  | 0.820  |   0.843  |     10.2   |
# | Arquitectura 3 | 0.840 |    0.863  | 0.811  |   0.821  |     11.4   |
# | Arquitectura 4 | 0.754 |    0.786  | 0.794  |   0.761  |     16.1   |
# | Arquitectura 5 | 0.869 |    0.896  | 0.785  |   0.823  |     26.2   |

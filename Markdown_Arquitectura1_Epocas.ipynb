# %% [markdown]
# ### Impacto del número de épocas (Arquitectura 1)
# | Épocas | Accuracy | Precision | Recall | F1-score | Tiempo (s) |
# |--------|----------|-----------|--------|----------|------------|
# | 10     |  0.883   |   0.882   | 0.871  |  0.872   |    3.71    |
# | 20     |  0.884   |   0.881   | 0.874  |  0.875   |    7.32    |
# | 30     |  0.869   |   0.862   | 0.852  |  0.854   |    11.20   |
# | 40     |  0.878   |   0.874   | 0.854  |  0.862   |    14.82   |
# | 50     |  0.883   |   0.885   | 0.861  |  0.870   |    18.40   |
